# %% [markdown]
# # Project #1 Table Extraction : Extract Tables from Websites

# %% [markdown]
# Target Website: <a href="https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes_(seasons_1%E2%80%9320)">Simpson's Wikipedia Page</a>

# %%
#Importing libraries
import pandas as pd

# %%
#To read all html table
simpsons = pd.read_html('https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes_(seasons_1%E2%80%9320)')

#Count of total no. of tables
len(simpsons)
# Out:
# 24

# %%
#Istalling lxml as a dependecy
# %pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB 119.1 kB/s eta 0:00:32
#    ---------------------------------------- 0.0/3.8 MB 119.1 kB/s eta 0:00:32
#    ---------------------------------------- 0.0/3.8 MB 122.9 kB/s eta 0:00:31
#     --------------------------------------- 0.1/3.8 MB 172.4 kB/s eta 0:00:22
#     --------------------------------------- 0.1/3.8 MB 228.2 kB/s eta 0:00:17
#    - -------------------------------------- 0.1/3.8 MB 304.6 kB/s eta 0:00:13
# ...

# %%
simpsons[1]
# Out:
#     No. overall  No. in season                                Title  \
# 0             1              1  "Simpsons Roasting on an Open Fire"
# 1             2              2                    "Bart the Genius"
# 2             3              3                    "Homer's Odyssey"
# 3             4              4      "There's No Disgrace Like Home"
# 4             5              5                   "Bart the General"
# 5             6              6                       "Moaning Lisa"
# 6             7              7           "The Call of the Simpsons"
# 7             8              8                  "The Telltale Head"
# 8             9              9              "Life on the Fast Lane"
# 9            10             10                  "Homer's Night Out"
# 10           11             11                "The Crepes of Wrath"
# 11           12             12                 "Krusty Gets Busted"
# 12           13             13             "Some Enchanted Evening"
#
# ...
